# %%
num1 = 5
num2 = 8
sum = num1+ num2
print(sum)
# Out:
# 13

# %%
a = 10
b = 20
c = 30
resultadoFinal = a + b + c
print(resultadoFinal)
# Out:
# 60

# %%
saludo = 'Hola '
nombre = 'Felipe'

mensajeCompleto = saludo + nombre
print(mensajeCompleto)
# Out:
# Hola Felipe

# %%
a = 1
b = "1"
type(a)
type(b)
# Out:
# str
